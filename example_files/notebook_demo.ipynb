# %%
import matplotlib.pyplot as plt
from draw_rna.ipynb_draw import draw_struct
# %load_ext autoreload
# %autoreload 2
import numpy as np

# %store -r test
# ........ .....(((((((((....((((((((((.(((.((((((((((.(((((((...)))))))))))))))).)...((((((((((((((((.(..........).))))))))))))))))..(((.(((((........((((((((....))))))))........))))).))).....))).))).)))))))))).)))))). .
# GGGAUAAU UGAUGGGCAUCUCCGUGGGGCUCCGCCCGGGCUCCCGGGGGGCCGCCCCCCGGGGGGGGGCGCCCCCCGGUGGUGGGGGCGCGUGCGUGUGGGUGUGUGUGUGUGUGUGUGUGCGUGUUCUGUGUUGGGUGCUGUGUCUGUGUGCGUUGGGCGACGUGCGGUUCCCUUGUGCUGGGCUGUUUGUCGGGGCCGGGGCCGGACGGUGUUA C
seq =     'UGAUGGGCAUCUCCGUGGGGCUCCGCCCGGGCUCCCGGGGGGCCGCCCCCCGGGGGGGGGCGCCCCCCGGUGGUGGGGGCGCGUGCGUGUGGGUGUGUGUGUGUGUGUGUGUGCGUGUUCUGUGUUGGGUGCUGUGUCUGUGUGCGUUGGGCGACGUGCGGUUCCCUUGUGCUGGGCUGUUUGUCGGGGCCGGGGCCGGACGGUGUUA'
struct =  '.....(((((((((....((((((((((.(((..(((((((((.(((((((...)))))))))))))))).....((((((((..((..((.(..(....)..).))..))..))))))))..(((.((..(........((..((((....))))..))........)..)).))).....))).)))).))))))))).)))))).'
energies = np.array(test)
energies += abs(min(energies))
energies *= 255.0/max(energies)
# print(energies)
# draw_struct(seq, struct, energies, cmap='RdBu_r', numbering=list(range(1,209)))
draw_struct(seq, struct, cmap='RdBu_r', numbering=list(range(1,len(seq)+1)))

# %%
# color with a random color vector

seq = 'AAuUGAUGGGCAUCUCCGUGGGGCUCCGCCCGGGCUCCCGGGGGGCCGCCCCCCGGGGGGGGGCGCCCCCCGGUGGUGGGGGCGCGUGCGUGUGGGUGUGUGUGUGUGUGUGUGUGCGUGUUCUGUGUUGGGUGCUGUGUCUGUGUGCGUUGGGCGACGUGCGGUUCCCUUGUGCUGGGCUGUUUGUCGGGGCCGGGGCCGGACGGUGUUACAA'.upper()
struct = '........(((((((((....((((((((((.(((..(((((((((.(((((((...)))))))))))))))).....((((((((..((..((.(..(....)..).))..))..))))))))..(((.((..(........((..((((....))))..))........)..)).))).....))).)))).))))))))).))))))....'
draw_struct(seq, struct, cmap='RdBu_r', numbering=list(range(1,len(seq)+1)))

# %%
seq = 'GGGAUAAUUGAUGGGCAUCUCCGUGGGGCUCCGCCCGGGCUCCCGGGGGGCCGCCCCCCGGGGGGGGGCGCCCCCCGGUGGUGGGGGCGCGUGCGUGUGGGUGUGUGUGUGUGUGUGUGUGCGUGUUCUGUGUUGGGUGCUGUGUCUGUGUGCGUUGGGCGACGUGCGGUUCCCUUGUGCUGGGCUGUUUGUCGGGGCCGGGGCCGGACGGUGUUAC'
struct = '(((((...........))))).((((.(((((((((.(((.(((((.(((((((((.(.((.((((....)))))))).))))((((((((((((((((.(..........).))))))))))))))))..(((.(((((........((((((((....))))))))........))))).))).)))).)))))))).))).))))..)).))))'
draw_struct(seq, struct, cmap='RdBu_r', numbering=list(range(1,len(seq)+1)))

# %%
seq = 'GGGAUAAUUGAUGGGCAUCUCCGUGGGGCUCCGCCCGGGCUCCCGGGGGGCCGCCCCCCGGGGGGGGGCGCCCCCCGGUGGUGGGGGCGCGUGCGUGUGGGUGUGUGUGUGUGUGUGUGUGCGUGUUCUGUGUUGGGUGCUGUGUCUGUGUGCGUUGGGCGACGUGCGGUUCCCUUGUGCUGGGCUGUUUGUCGGGGCCGGGGCCGGACGGUGUUAC'
struct = '.............(((((((((....((((((((((.(((.((((((((((.(((((((...)))))))))))))))).)...((((((((((((((((.(..........).))))))))))))))))..(((.(((((........((((((((....))))))))........))))).))).....))).))).)))))))))).))))))..'
draw_struct(seq, struct, cmap='RdBu_r', numbering=list(range(1,len(seq)+1)))

# %%
# Make subplots, play with transparency

seq='CGCUGUCUGUACUUGUAUCAGUACACUGACGAGUCCCUAAAGGACGAAACAGCG'
struct='((((((.((((((......)))))).......((((.....))))...))))))'

fig, axes = plt.subplots(2,3,figsize=(25,10))

for i, ax in enumerate(axes.flat):
    draw_struct(seq, struct, ax=ax, c=np.random.uniform(size=len(seq)),
                alpha = np.concatenate([np.ones(len(seq)-10),0.1*np.ones(10)]))
