# %%
import matplotlib.pyplot as plt
import matplotlib
import glob
from pathlib import Path

from draw_rna.wrapper_functions import *
# %load_ext autoreload
# %autoreload 2
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['svg.fonttype'] = 'none'

# %%
folders = [
    '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR',
    '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/ADD-Woodside',
    '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/GGV-S-IGR-presentation',
]
files = []
for folder in folders:
    for path in Path(folder).rglob('*.dt'):
        if 'unfolding' in path.as_posix(): continue
        if 'vsfold5' in path.as_posix(): continue
        files.append(path.as_posix())
print(files[20])
print(files[21])

# %%
# for file in files:
#     final_list, final_str_list, seq, db, structures = ct_to_paired_list_count_all(file)
#     print(seq)
print(len(files))
# %tb
# Out:
# 37

# %%
store_path = '/home/dwarrel/Pictures/cover/small_structures_svg/'
for idx, file in enumerate(files):
    #if idx != 21: continue
    plt.close('all')
    try:
        x = create_figure(file, predict=False, show_energies=False, energies_individual=False, large_mode=False, numbering=0, segment_lenghts=False, show_primes=False, colors='black', file_name=store_path+str(idx), store_plt_svg=False, show_plot=False, return_ax=True)
        plt.savefig(store_path+str(idx)+'.svg', bbox_inches='tight',transparent=True)
    except Exception as e:
        continue
    # break
# Out:
# Error occured while drawing RNA 49 48
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
store_path = '/home/dwarrel/Pictures/cover/small_structures_colour_svg/'
for idx, file in enumerate(files):
    #if idx != 21: continue
    plt.close('all')
    try:
        x = create_figure(file, return_ax=True, predict=False, show_energies=False, energies_individual=False, large_mode=False, numbering=0, segment_lenghts=False, show_primes=False, file_name=store_path+str(idx), store_plt_svg=False, show_plot=False)
        plt.savefig(store_path+str(idx)+'.svg', bbox_inches='tight',transparent=True)
    except Exception as e:
        continue
# Out:
# Error occured while drawing RNA 49 48
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
store_path = '/home/dwarrel/Pictures/cover/small_structures_stiff_svg/'
for idx, file in enumerate(files):
    # if idx != 21: continue
    plt.close('all')
    try:
        x = create_figure(file, predict=False, show_energies=False, energies_individual=False, large_mode=True, numbering=0, segment_lenghts=False, show_primes=False, colors='black', file_name=store_path+str(idx), store_plt_svg=False, show_plot=False)
        plt.savefig(store_path+str(idx)+'.svg', bbox_inches='tight',transparent=True)
    except Exception as e:
        continue
# Out:
# Error occured while drawing RNA 49 48
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
store_path = '/home/dwarrel/Pictures/cover/small_structures_stiff_colour_svg/'
for idx, file in enumerate(files):
    # if idx != 21: continue
    plt.close('all')
    try:
        x = create_figure(file, return_ax=True, predict=False, show_energies=False, energies_individual=False, large_mode=True, numbering=0, segment_lenghts=False, show_primes=False, file_name=store_path+str(idx), store_plt_svg=False, show_plot=False)
        plt.savefig(store_path+str(idx)+'.svg', bbox_inches='tight',transparent=True)
    except Exception as e:
        continue
# Out:
# Error occured while drawing RNA 49 48
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
