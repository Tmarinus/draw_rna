# %%
import matplotlib.pyplot as plt
from draw_rna.ipynb_draw import draw_struct
# %load_ext autoreload
# %autoreload 2
import numpy as np

def draw_ct(file_path):
    with open(file_path, 'r') as file:
        seq = file.readline().strip()
        struct = file.readline().strip()
    draw_struct(seq.upper(), struct, cmap='RdBu_r', numbering=list(range(1,len(seq)+1)), large_mode=True)

# %%
unrest = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/ct2dot_LCMVL_UNRESTRAINED.txt'
rest = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/unfolding_steps/folded.dt'
draw_ct(unrest)
draw_ct(rest)
