# %%
# import matplotlib.pyplot as plt
# from draw_rna.ipynb_draw import draw_struct
# import os
# import re
# from RNA import RNA
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2   
import sys
sys.path.append('/home/dwarrel/projects/temp-gits/nooverlap')

# %%
print(sys.path)
pusher = test()
# Out:
# ['/home/dwarrel/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python/helpers-pro/jupyter_debug', '/home/dwarrel/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python/helpers/pydev', '/home/dwarrel/projects/temp-gits/draw_rna/example_files', '/home/dwarrel/projects/temp-gits/draw_rna/src', '/home/dwarrel/anaconda3/envs/sweet-jupyter/lib/python312.zip', '/home/dwarrel/anaconda3/envs/sweet-jupyter/lib/python3.12', '/home/dwarrel/anaconda3/envs/sweet-jupyter/lib/python3.12/lib-dynload', '', '/home/dwarrel/anaconda3/envs/sweet-jupyter/lib/python3.12/site-packages', '/home/dwarrel/projects/temp-gits/nooverlap', '/home/dwarrel/anaconda3/envs/sweet-jupyter/lib/python3.12/site-packages/setuptools/_vendor']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 print(sys.path)
# ----> 2 import nooverlap
# ...
