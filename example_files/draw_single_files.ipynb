# %%
import matplotlib.pyplot as plt
import matplotlib

from draw_rna.wrapper_functions import *
# %load_ext autoreload
# %autoreload 2
# matplotlib.use("pgf")
# matplotlib.rcParams.update({
#     "pgf.texsystem": "pdflatex",
#     'font.family': 'serif',
#     'text.usetex': True,
#     'pgf.rcfonts': False,
# })
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['svg.fonttype'] = 'none'

# %%
file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/GGV-S-IGR-presentation/dots/2.dt'
# store_path = '/home/dwarrel/projects/final_thesis/Introduction/figures/centroid_IGR_S.pgf'
fakes = [(114,1)]
x = create_figure(file_path, predict=False, show_energies=False, energies_individual=False, large_mode=True, numbering=0, custom_line=True, segment_lenghts=False, store_plt_svg=True, add_fake=fakes)
# Out:
# saving svg/pdf as /home/dwarrel/Documents/data/Arenavirus/mfold_pages/GGV-S-IGR-presentation/dots/2
# True

# %%
file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/ct2dot_LCMVL_RESTRAINED_reduced-to-ot-size_quickedit.dt'
# store_path = '/home/dwarrel/projects/final_thesis/Introduction/figures/centroid_IGR_S.pgf'
fakes = [(21,2)]
fakes = []
x = create_figure(file_path, predict=False, show_energies=False, energies_individual=False, large_mode=True, numbering=0, custom_line=True, segment_lenghts=False, store_plt_svg=True, add_fake=fakes)
# Out:
# saving svg/pdf as /home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/ct2dot_LCMVL_RESTRAINED_reduced-to-ot-size_quickedit
# True

# %%
file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR-presentation/dots/1_removed_linkers.dt'
store_path = '/home/dwarrel/projects/final_thesis/Introduction/figures/mfold_1_LCMV_igr_L.pgf'
fakes = [(114,1)]
x = create_figure(file_path, predict=False, show_energies=False, energies_individual=False, large_mode=True, numbering=0, custom_line=True, segment_lenghts=False, colors='black', file_name=store_path, store_plt_svg=True, add_fake=fakes)
# Out:
# saving svg/pdf as /home/dwarrel/projects/final_thesis/Introduction/figures/mfold_1_LCMV_igr_L.pgf

# %%
db =  '.....((((...)))).........(((((((.....))))))).....'
seq = ''.join([' ' for _ in db])
print(seq)
store_path = '/home/dwarrel/projects/final_thesis/sweet-potato/figures/tmp/fake_struct1.svg'
x = create_figure(file_path=None, seq=seq, db=db, predict=False, show_energies=False, energies_individual=False, large_mode=True, numbering=0, custom_line=True, segment_lenghts=False, colors='black', store_plt_svg=True, file_name=store_path)
store_path = '/home/dwarrel/projects/final_thesis/sweet-potato/figures/tmp/fake_struct2.svg'
db =  '.........................(((((((.....))))))).....'
x = create_figure(file_path=None, seq=seq, db=db, predict=False, show_energies=False, energies_individual=False, large_mode=True, numbering=0, custom_line=True, segment_lenghts=False, colors='black', store_plt_svg=True, file_name=store_path)
store_path = '/home/dwarrel/projects/final_thesis/sweet-potato/figures/tmp/fake_struct3.svg'
db =  '.................................................'
x = create_figure(file_path=None, seq=seq, db=db, predict=False, show_energies=False, energies_individual=False, large_mode=True, numbering=0, custom_line=True, segment_lenghts=False, colors='black', store_plt_svg=True, file_name=store_path)
# Out:
#
# 49
# saving svg/pdf as /home/dwarrel/projects/final_thesis/sweet-potato/figures/tmp/fake_struct1.svg
# 49
# saving svg/pdf as /home/dwarrel/projects/final_thesis/sweet-potato/figures/tmp/fake_struct2.svg
# 49
# saving svg/pdf as /home/dwarrel/projects/final_thesis/sweet-potato/figures/tmp/fake_struct3.svg
