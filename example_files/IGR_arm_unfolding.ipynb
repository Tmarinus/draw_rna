# %%
import matplotlib.pyplot as plt

from draw_rna.wrapper_functions import *
# %load_ext autoreload

plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['svg.fonttype'] = 'none'
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
settings = get_default_settings()
file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_removed_linkers.dt'
create_figure(file_path, predict=True, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True, salt=.2)
# Out:
# energy -94.69000244140625
# 208
# ('3.54',
#  {5: -0.5,
#   206: -0.5,
#   6: -2.5,
#   205: -2.5,
#   7: -2.1,
#   204: -2.1,
#   8: -1.4,
#   203: -1.4,
#   9: -1.5,
#   202: -1.5,
#   10: 1.7,
#   201: 1.7,
#   11: -2.4,
#   199: -2.4,
#   12: -3.3,
#   198: -3.3,
#   13: 3.6,
#   197: 3.6,
#   18: -3.3,
#   196: -3.3,
#   19: -3.4,
#   195: -3.4,
#   20: -2.1,
#   194: -2.1,
#   21: -1.5,
#   193: -1.5,
#   22: -3.3,
#   192: -3.3,
#   23: -2.4,
#   191: -2.4,
#   24: 0.4,
#   190: 0.4,
#   25: -3.3,
#   188: -3.3,
#   26: -3.3,
#   187: -3.3,
#   27: -1.4,
#   186: -1.4,
#   29: -1.5,
#   184: -1.5,
#   30: -2.5,
#   183: -2.5,
#   31: 2.7,
#   182: 2.7,
#   32: -1.5,
#   72: -1.5,
#   33: 0.5,
#   71: 0.5,
#   34: -3.3,
#   69: -3.3,
#   35: -2.4,
#   68: -2.4,
#   36: -3.3,
#   67: -3.3,
#   37: -3.3,
#   66: -3.3,
#   38: -3.3,
#   65: -3.3,
#   39: -3.3,
#   64: -3.3,
#   40: -3.3,
#   63: -3.3,
#   41: -3.4,
#   62: -3.4,
#   42: 1.4,
#   61: 1.4,
#   44: -3.4,
# ...

# %%
file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_Leftonly.dt'
# file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_toponly.dt'
# file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_righttonly.dt'
# create_figure(file_path, predict=True, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True)
constraints=list(range(0,14))+list(range(197,208))
restrict = []
i, j = 0, 36
while i<j:
    print(restrict)
    energies = create_figure(file_path, predict=True, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True, constraints=restrict, salt=0.2, store_plt_svg=True, file_name=f"/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/unfolding_arms/left_{i}")
    if len(energies) == 0: break
    restrict += [i,j]
    i += 1
    j -= 1
    break
    # break
# Out:
# []
# energy -37.81999969482422
# 36
# saving svg/pdf as /home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/unfolding_arms/left_0

# %%
# file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_Leftonly.dt'
file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_toponly.dt'
# file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_righttonly.dt'
# create_figure(file_path, predict=True, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True)
constraints=list(range(0,14))+list(range(197,208))
restrict = []
i, j = 0, 45
while i<j:
    print(restrict)
    energies = create_figure(file_path, predict=True, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=False, constraints=restrict, salt=0.2, store_plt_svg=True, file_name=f"/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/unfolding_arms/top_{i}")
    if len(energies) == 0: break
    restrict += [i,j]
    i += 1
    j -= 1
    break
# Out:
# []
# energy -10.5600004196167
# 46
# saving svg/pdf as /home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/unfolding_arms/top_0

# %%
# file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_Leftonly.dt'
# file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_toponly.dt'
file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_righttonly.dt'
# create_figure(file_path, predict=True, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True)
constraints=list(range(0,14))+list(range(197,208))
restrict = []
i, j = 0, 53
while i<j:
    print(restrict)
    energies = create_figure(file_path, predict=True, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True, constraints=restrict, salt=0.2, store_plt_svg=True, file_name=f"/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/unfolding_arms/right_{i}")
    if len(energies) == 0: break
    restrict += [i,j]
    i += 1
    j -= 1
    break
# Out:
# []
# energy -13.479999542236328
# 54
# saving svg/pdf as /home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/unfolding_arms/right_0

# %%
# file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_Leftonly.dt'
# file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_toponly.dt'
# file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/ct2dot_LCMVL_RESTRAINED_cleaned_tmp_left.txt'
seq1 = 'CGCCCCCCGGGGGGGGGCGCCCCCCGGUGGUG'
# db = predict_structure(seq1) # predicted RNAstructure
seq1 = 'CGCCCCCCGGGGGGGGGCGCCCCCCGGUGGUG'
db1 = '(((((.(.((.((((....)))))))).))))' # predicted orbisims
seq11 = 'CGCCCCCCGGGGGGGGGCGCCCCCCGGUGGUG'
db11 = '((((..((((((((.....)))))))).))))' # Predicted mfold
print_energy_list(seq1, db1) # orbi
# print_energy_list(seq1, db) # rnastruct
# print_energy_list(seq11, db11) #mfold
x = create_figure(None, seq1, db1, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True)
# x = create_figure(None, seq1, db, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True)
# x = create_figure(None, seq11, db11, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True)
seq11 = 'CCGGGGGGCCGCCCCCCGGGGGGGGGCGCCCCCCGGU'
db11 = '(((((((((.(((((((...)))))))))))))))).' # Predicted mfold
print_energy_list(seq11, db11) #mfold
x = create_figure(None, seq11, db11, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True)
db11 = predict_structure(seq11)
print_energy_list(seq11, db11) # orbi
x = create_figure(None, seq11, db11, predict=True, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True)
# Out:
# -14.1
# 32
# -39.3
# 37
# energy -39.29999923706055
# -39.3
# energy -39.29999923706055
# 37

# %%
seq2 = 'GGGGCGCGUGCGUGUGGGUGUGUGUGUGUGUGUGUGUGCGUGUUCU'
db2 = '((((((((((((((((.(..........).))))))))))))))))' #orbisims
db = predict_structure(seq2) # predicted RNAstructure
print_energy_list(seq2, db2) 
print_energy_list(seq2, db) 
db3 = '((((((((..((..((.(..(....)..).))..))..))))))))' # mfold
print_energy_list(seq2, db3) 
x = create_figure(None, seq2, db2, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-orbi.pdf', store_plt_svg=True, color_map=True)
x = create_figure(None, seq2, db, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-RNAstructure.pdf', store_plt_svg=True, color_map=True)
x = create_figure(None, seq2, db3, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-Mfold.pdf', store_plt_svg=True, color_map=True)
# Out:
# energy -11.300000190734863
# -9.6
# -11.3
# -1.1
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-orbi.pdf
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-RNAstructure.pdf
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-Mfold.pdf

# %%
seqR = 'GUGUUGGGUGCUGUGUCUGUGUGCGUUGGGCGACGUGCGGUUCCCUUGUGCUGGGCU'
dbR = '..(((.(((((........((((((((....))))))))........))))).))).' # orbisims
dbR2 = predict_structure(seqR) # RNAstructure
print_energy_list(seqR, dbR)
print_energy_list(seqR, dbR2)
dbR3 = '..(((.((..(........((..((((....))))..))........)..)).))).' # Mfold
print_energy_list(seqR, dbR3)
x = create_figure(None, seqR, dbR, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-orbi.pdf', store_plt_svg=True, color_map=True)
x = create_figure(None, seqR, dbR2, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-RNAstructure.pdf', store_plt_svg=True, color_map=True)
x = create_figure(None, seqR, dbR3, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-Mfold.pdf', store_plt_svg=True, color_map=True, )
# Out:
# energy -16.299999237060547
# -16.3
# -16.3
# -4.9
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-orbi.pdf
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-RNAstructure.pdf
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-Mfold.pdf

# %%
seqR = 'GUGUUGGGUGCUGUGUCUGUGUGCGUUGGGCGACGUGCGGUUCCCUUGUGCUGGGCU'
# dbR = '..(((.(((((........((((((((....))))))))........))))).))).' # orbisims
dbR = '......(((((........((((((((....))))))))........))))).....' # orbisims not 4nm start
dbR2 = predict_structure(seqR, constraints=[0,1,2,3,4,5, 52,53,54,55,56]) # RNAstructure
# dbR2 = predict_structure(seqR) # RNAstructure
print_energy_list(seqR, dbR)
print_energy_list(seqR, dbR2)
dbR3 = '......((..(........((..((((....))))..))........)..)).....' # Mfold
print_energy_list(seqR, dbR3)
x = create_figure(None, seqR, dbR, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-shorter-orbi.pdf', store_plt_svg=True, color_map=True)
x = create_figure(None, seqR, dbR2, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-shorter-RNAstructure.pdf', store_plt_svg=True, color_map=True)
x = create_figure(None, seqR, dbR3, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-shorter-Mfold.pdf', store_plt_svg=True, color_map=True)
# Out:
# energy -16.299999237060547
# -11.7
# -16.3
# -0.3
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-shorter-orbi.pdf
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-shorter-RNAstructure.pdf
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/right-shorter-Mfold.pdf

# %%
seq2 = 'CCGGGGGGCCGCCCCCCGGGGGGGGGCGCCCCCCGGU'
db2 = '(((((((((.(((((((...)))))))))))))))).' #mfold
db = predict_structure(seq2) # predicted RNAstructure
print_energy_list(seq2, db2) 
print_energy_list(seq2, db)
db3 = '((((((((..((..((.(..(....)..).))..))..))))))))' # mfold
print(db)
print(db3)
print_energy_list(seq2, db3)
# x = create_figure(None, seq2, db2, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-orbi.pdf', store_plt_svg=False, color_map=True)
# x = create_figure(None, seq2, db, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-RNAstructure.pdf', store_plt_svg=False, color_map=True)
# x = create_figure(None, seq2, db3, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-Mfold.pdf', store_plt_svg=False, color_map=False)
# Out:
# energy -39.29999923706055
# -39.3
# -39.3
# (((((((((.(((((((...)))))))))))))))).
# ((((((((..((..((.(..(....)..).))..))..))))))))
# 0.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 12
#      10 x = create_figure(None, seq2, db2, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-orbi.pdf', store_plt_svg=False, color_map=True)
#      11 x = create_figure(None, seq2, db, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/Up-RNAstructure.pdf', store_plt_svg=False, color_map=True)
# ...

# %%
file_path = '/home/dwarrel/Documents/data/Arenavirus/mfold_pages/LMVC-L-IGR/dots/1_Leftonly.dt'
x = create_figure(file_path, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/left_mfold.pdf', store_plt_svg=True, color_map=True)
x = create_figure(file_path, predict=True, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/left_rnastructure.pdf', store_plt_svg=True, color_map=True)
seq = 'CGCCCCCCGGGGGGGGGCGCCCCCCGGUGGUG'
# dbR = '..(((.(((((........((((((((....))))))))........))))).))).' # orbisims
db = '(((((.(.((.((((....)))))))).))))' # orbisims not 4nm start
x = create_figure(None, seq, db, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/left_orbi.pdf', store_plt_svg=True, color_map=True)
x = create_figure(None, seq, db, predict=True, show_energies=True, energies_individual=True, large_mode=True, numbering=0, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/left_orbi_seq_rnastructure_predict.pdf', store_plt_svg=True, color_map=True)
# Out:
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/left_mfold.pdf
# energy -38.70000076293945
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/left_rnastructure.pdf
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/left_orbi.pdf
# energy -23.600000381469727
# saving svg/pdf as /home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/left_orbi_seq_rnastructure_predict.pdf

# %%
x = create_figure(None, seq, db, show_energies=True, energies_individual=True, large_mode=True, numbering=5, custom_line=True, file_name='/home/dwarrel/projects/final_thesis/IGR/figures_2/tmp/left_orbi.png', store_plt_svg=False, color_map=(-5,10))
